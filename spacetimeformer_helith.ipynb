# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/spacetimeformer
# Out:
# /content/drive/MyDrive/spacetimeformer

# %%
# !pip install pip==24.0
# Out:
# Collecting pip==24.0
#   Downloading pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 71.7 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-24.0

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: Cython>=0.22 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 1)) (3.0.11)
# Collecting cmdstanpy==0.9.68 (from -r requirements.txt (line 2))
#   Downloading cmdstanpy-0.9.68-py3-none-any.whl.metadata (3.7 kB)
# Collecting pystan~=2.19.1.1 (from -r requirements.txt (line 3))
#   Downloading pystan-2.19.1.1.tar.gz (16.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.2/16.2 MB 77.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 4)) (1.26.4)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (2.1.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (3.7.1)
# Collecting convertdate>=2.1.2 (from -r requirements.txt (line 7))
#   Downloading convertdate-2.4.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 8)) (2.8.2)
# Collecting performer-pytorch (from -r requirements.txt (line 9))
#   Downloading performer_pytorch-1.1.4-py3-none-any.whl.metadata (763 bytes)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 10)) (4.66.5)
# Collecting nystrom-attention (from -r requirements.txt (line 11))
#   Downloading nystrom_attention-0.0.12-py3-none-any.whl.metadata (657 bytes)
# Collecting pytorch-lightning==1.6 (from -r requirements.txt (line 12))
#   Downloading pytorch_lightning-1.6.0-py3-none-any.whl.metadata (33 kB)
# Collecting netCDF4 (from -r requirements.txt (line 13))
#   Downloading netCDF4-1.7.1.post2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 14)) (1.3.2)
# Collecting omegaconf (from -r requirements.txt (line 15))
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 16)) (0.13.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 17)) (4.10.0.84)
# Collecting wandb (from -r requirements.txt (line 18))
#   Downloading wandb-0.17.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 19)) (0.8.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 20)) (5.2.0)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 21)) (3.3.0)
# Collecting torchmetrics==0.5.1 (from -r requirements.txt (line 22))
#   Downloading torchmetrics-0.5.1-py3-none-any.whl.metadata (15 kB)
# Collecting ujson (from cmdstanpy==0.9.68->-r requirements.txt (line 2))
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.6->-r requirements.txt (line 12)) (2.4.0+cu121)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.6->-r requirements.txt (line 12)) (6.0.2)
# Requirement already satisfied: fsspec!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (2024.6.1)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.6->-r requirements.txt (line 12)) (2.17.0)
# Collecting pyDeprecate<0.4.0,>=0.3.1 (from pytorch-lightning==1.6->-r requirements.txt (line 12))
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.6->-r requirements.txt (line 12)) (24.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.6->-r requirements.txt (line 12)) (4.12.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->-r requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->-r requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->-r requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->-r requirements.txt (line 6)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->-r requirements.txt (line 6)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->-r requirements.txt (line 6)) (3.1.2)
# Collecting pymeeus<=1,>=0.3.13 (from convertdate>=2.1.2->-r requirements.txt (line 7))
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 92.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->-r requirements.txt (line 8)) (1.16.0)
# Collecting local-attention>=1.1.1 (from performer-pytorch->-r requirements.txt (line 9))
#   Downloading local_attention-1.9.14-py3-none-any.whl.metadata (683 bytes)
# Collecting axial-positional-embedding>=0.1.0 (from performer-pytorch->-r requirements.txt (line 9))
#   Downloading axial_positional_embedding-0.2.1.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cftime (from netCDF4->-r requirements.txt (line 13))
#   Downloading cftime-1.6.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netCDF4->-r requirements.txt (line 13)) (2024.7.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r requirements.txt (line 14)) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r requirements.txt (line 14)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->-r requirements.txt (line 14)) (3.5.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->-r requirements.txt (line 15))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 14.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 18)) (8.1.7)
# Collecting docker-pycreds>=0.4.0 (from wandb->-r requirements.txt (line 18))
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb->-r requirements.txt (line 18))
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 18)) (4.2.2)
# Requirement already satisfied: protobuf!=4.21.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 18)) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 18)) (5.9.5)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 18)) (2.32.3)
# Collecting sentry-sdk>=1.0.0 (from wandb->-r requirements.txt (line 18))
#   Downloading sentry_sdk-2.13.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting setproctitle (from wandb->-r requirements.txt (line 18))
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb->-r requirements.txt (line 18)) (71.0.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (3.10.5)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 18))
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 18)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 18)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 18)) (2.0.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (3.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.*->pytorch-lightning==1.6->-r requirements.txt (line 12)) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.*->pytorch-lightning==1.6->-r requirements.txt (line 12)) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.*->pytorch-lightning==1.6->-r requirements.txt (line 12)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.*->pytorch-lightning==1.6->-r requirements.txt (line 12)) (3.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (4.0.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 18))
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning==1.6->-r requirements.txt (line 12)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.*->pytorch-lightning==1.6->-r requirements.txt (line 12)) (1.3.0)
# Downloading cmdstanpy-0.9.68-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 5.1 MB/s eta 0:00:00
# Downloading pytorch_lightning-1.6.0-py3-none-any.whl (582 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 582.1/582.1 kB 50.2 MB/s eta 0:00:00
# Downloading torchmetrics-0.5.1-py3-none-any.whl (282 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.0/283.0 kB 23.3 MB/s eta 0:00:00
# Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 5.6 MB/s eta 0:00:00
# Downloading performer_pytorch-1.1.4-py3-none-any.whl (13 kB)
# Downloading nystrom_attention-0.0.12-py3-none-any.whl (4.6 kB)
# Downloading netCDF4-1.7.1.post2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 108.0 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.3 MB/s eta 0:00:00
# Downloading wandb-0.17.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 70.8 MB/s eta 0:00:00
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 19.5 MB/s eta 0:00:00
# Downloading local_attention-1.9.14-py3-none-any.whl (9.0 kB)
# Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Downloading sentry_sdk-2.13.0-py2.py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 31.9 MB/s eta 0:00:00
# Downloading cftime-1.6.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.0 MB/s eta 0:00:00
# Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.3 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.9 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pystan, antlr4-python3-runtime, axial-positional-embedding, pymeeus
#   Building wheel for pystan (setup.py) ... done
#   Created wheel for pystan: filename=pystan-2.19.1.1-cp310-cp310-linux_x86_64.whl size=61975274 sha256=33745cb860bd7c794ca3c5bdb21e2d36a540454d257a606d9ef2f9e814826ee4
#   Stored in directory: /root/.cache/pip/wheels/3d/1c/94/4516243362eedbedad15ac4389691ee3bf2d45bec2639c9d8b
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=060031b386ba7fcb25f2e7d1949af77ec2e7cdc5e68218eb55ce075e695cfc7a
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for axial-positional-embedding (setup.py) ... done
#   Created wheel for axial-positional-embedding: filename=axial_positional_embedding-0.2.1-py3-none-any.whl size=2888 sha256=b1b41b07838dce9d01382ced20ab7156cbf57e259c967f5664e1cd9ac01fef1b
#   Stored in directory: /root/.cache/pip/wheels/b1/cb/39/7ce7ff2d2fd37cfe1fe7b3a3c43cf410632b2ad3b3f3986d73
#   Building wheel for pymeeus (setup.py) ... done
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=731999 sha256=591d7d7b049b1bdc1e15149e92d322d555cdad5ceb9a31ccba63e6737ecb39d3
#   Stored in directory: /root/.cache/pip/wheels/d6/67/78/aa2e8d108639dd23a5e9e72a4fc88bb44f5541894382712f48
# Successfully built pystan antlr4-python3-runtime axial-positional-embedding pymeeus
# DEPRECATION: pytorch-lightning 1.6.0 has a non-standard dependency specifier torch>=1.8.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: pymeeus, antlr4-python3-runtime, ujson, smmap, setproctitle, sentry-sdk, pystan, pyDeprecate, omegaconf, docker-pycreds, convertdate, cftime, netCDF4, gitdb, torchmetrics, nystrom-attention, local-attention, gitpython, cmdstanpy, axial-positional-embedding, wandb, pytorch-lightning, performer-pytorch
#   Attempting uninstall: cmdstanpy
#     Found existing installation: cmdstanpy 1.2.4
#     Uninstalling cmdstanpy-1.2.4:
#       Successfully uninstalled cmdstanpy-1.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# prophet 1.1.5 requires cmdstanpy>=1.0.4, but you have cmdstanpy 0.9.68 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 axial-positional-embedding-0.2.1 cftime-1.6.4 cmdstanpy-0.9.68 convertdate-2.4.0 docker-pycreds-0.4.0 gitdb-4.0.11 gitpython-3.1.43 local-attention-1.9.14 netCDF4-1.7.1.post2 nystrom-attention-0.0.12 omegaconf-2.3.0 performer-pytorch-1.1.4 pyDeprecate-0.3.2 pymeeus-0.5.12 pystan-2.19.1.1 pytorch-lightning-1.6.0 sentry-sdk-2.13.0 setproctitle-1.3.3 smmap-5.0.1 torchmetrics-0.5.1 ujson-5.10.0 wandb-0.17.7

# %%
cd /content/drive/MyDrive/spacetimeformer
# Out:
# /content/drive/MyDrive/spacetimeformer

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/spacetimeformer
#   Preparing metadata (setup.py) ... done
# DEPRECATION: pytorch-lightning 1.6.0 has a non-standard dependency specifier torch>=1.8.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: spacetimeformer
#   Running setup.py develop for spacetimeformer
# Successfully installed spacetimeformer-1.5.0

# %%
cd spacetimeformer
# Out:
# /content/drive/MyDrive/spacetimeformer/spacetimeformer

# %%
# !python train.py spacetimeformer bus --start_token_len 3 --batch_size 5 \
--gpus 0 --grad_clip_norm 1 --d_model 128 --d_ff 512 --enc_layers 5 \
--dec_layers 4 --dropout_emb .3 --dropout_ff .3 --dropout_qkv 0 \
--run_name spatiotemporal_metr-la --base_lr 1e-3 --l2_coeff 1e-2
# Out:
# 2024-08-28 16:38:49.876730: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-28 16:38:49.894680: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-28 16:38:49.916243: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-28 16:38:49.922764: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-28 16:38:49.938391: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-28 16:38:51.043535: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/local_attention/rotary.py:33: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# /usr/local/lib/python3.10/dist-packages/local_attention/rotary.py:55: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @autocast(enabled = False)
# Using default wandb log dir path of ./data/STF_LOG_DIR. This can be adjusted with the environment variable `STF_LOG_DIR`
# /content/drive/MyDrive/spacetimeformer/spacetimeformer/data/timefeatures.py:24: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   main_df["Month"] = dates.apply(
# /content/drive/MyDrive/spacetimeformer/spacetimeformer/data/timefeatures.py:28: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   main_df["Day"] = dates.apply(lambda row: 2.0 * ((row.day - 1) / 30.0) - 1.0, 1)
# /content/drive/MyDrive/spacetimeformer/spacetimeformer/data/timefeatures.py:30: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   main_df["Weekday"] = dates.apply(
# /content/drive/MyDrive/spacetimeformer/spacetimeformer/data/timefeatures.py:34: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   main_df["Hour"] = dates.apply(lambda row: 2.0 * ((row.hour) / 23.0) - 1.0, 1)
# /content/drive/MyDrive/spacetimeformer/spacetimeformer/data/timefeatures.py:36: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   main_df["Minute"] = dates.apply(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/lightning.py:2046: DeprecationWarning: `torch.distributed._sharded_tensor` will be deprecated, use `torch.distributed._shard.sharded_tensor` instead
#   from torch.distributed._sharded_tensor import pre_load_state_dict_hook, state_dict_hook
# Forecaster
# 	L2: 0.01
# 	Linear Window: 0
# 	Linear Shared Weights: False
# 	RevIN: False
# 	Decomposition: False
# GlobalSelfAttn: AttentionLayer(
#   (inner_attention): PerformerAttention(
#     (kernel_fn): ReLU()
#   )
#   (query_projection): Linear(in_features=128, out_features=800, bias=True)
#   (key_projection): Linear(in_features=128, out_features=800, bias=True)
#   (value_projection): Linear(in_features=128, out_features=800, bias=True)
#   (out_projection): Linear(in_features=800, out_features=128, bias=True)
#   (dropout_qkv): Dropout(p=0.0, inplace=False)
# )
# GlobalCrossAttn: AttentionLayer(
#   (inner_attention): PerformerAttention(
#     (kernel_fn): ReLU()
#   )
#   (query_projection): Linear(in_features=128, out_features=800, bias=True)
#   (key_projection): Linear(in_features=128, out_features=800, bias=True)
#   (value_projection): Linear(in_features=128, out_features=800, bias=True)
#   (out_projection): Linear(in_features=800, out_features=128, bias=True)
#   (dropout_qkv): Dropout(p=0.0, inplace=False)
# )
# LocalSelfAttn: AttentionLayer(
#   (inner_attention): PerformerAttention(
#     (kernel_fn): ReLU()
#   )
#   (query_projection): Linear(in_features=128, out_features=800, bias=True)
#   (key_projection): Linear(in_features=128, out_features=800, bias=True)
#   (value_projection): Linear(in_features=128, out_features=800, bias=True)
#   (out_projection): Linear(in_features=800, out_features=128, bias=True)
#   (dropout_qkv): Dropout(p=0.0, inplace=False)
# )
# LocalCrossAttn: AttentionLayer(
#   (inner_attention): PerformerAttention(
#     (kernel_fn): ReLU()
#   )
#   (query_projection): Linear(in_features=128, out_features=800, bias=True)
#   (key_projection): Linear(in_features=128, out_features=800, bias=True)
#   (value_projection): Linear(in_features=128, out_features=800, bias=True)
#   (out_projection): Linear(in_features=800, out_features=128, bias=True)
#   (dropout_qkv): Dropout(p=0.0, inplace=False)
# )
# Using Embedding: spatio-temporal
# Time Emb Dim: 6
# Space Embedding: True
# Time Embedding: True
# Val Embedding: True
# Given Embedding: True
# Null Value: None
# Pad Value: None
# Reconstruction Dropout: Timesteps 0.05, Standard 0.1, Seq (max len = 5) 0.2, Skip All Drop 1.0
#  *** Spacetimeformer (v1.5) Summary: ***
# 		Model Dim: 128
# 		FF Dim: 512
# 		Enc Layers: 5
# 		Dec Layers: 4
# 		Embed Dropout: 0.3
# 		FF Dropout: 0.3
# 		Attn Out Dropout: 0.0
# 		Attn Matrix Dropout: 0.0
# 		QKV Dropout: 0.0
# 		L2 Coeff: 0.01
# 		Warmup Steps: 0
# 		Normalization Scheme: batch
# 		Attention Time Windows: 1
# 		Shifted Time Windows: False
# 		Position Emb Type: abs
# 		Recon Loss Imp: 0.0
#  ***                                  ***
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:287: LightningDeprecationWarning: Passing `Trainer(accelerator='dp')` has been deprecated in v1.5 and will be removed in v1.7. Use `Trainer(strategy='dp')` instead.
#   rank_zero_deprecation(
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name            | Type            | Params
# ----------------------------------------------------
# 0 | spacetimeformer | Spacetimeformer | 12.0 M
# ----------------------------------------------------
# 12.0 M    Trainable params
# 0         Non-trainable params
# 12.0 M    Total params
# 47.850    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 0:  40% 14/35 [00:03<00:04,  4.20it/s, loss=2.33]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0% 0/21 [00:00<?, ?it/s]
# Epoch 0:  97% 34/35 [00:04<00:00,  6.90it/s, loss=2.33]
# Epoch 0: 100% 35/35 [00:05<00:00,  6.85it/s, loss=2.33, val_loss=2.300]
# Epoch 1:  40% 14/35 [00:07<00:11,  1.75it/s, loss=0.772, val_loss=2.300]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0% 0/21 [00:00<?, ?it/s]
# Epoch 1:  97% 34/35 [00:09<00:00,  3.56it/s, loss=0.772, val_loss=2.300]
# Epoch 1: 100% 35/35 [00:09<00:00,  3.64it/s, loss=0.772, val_loss=1.250]
# Epoch 2:  40% 14/35 [00:12<00:18,  1.12it/s, loss=0.699, val_loss=1.250]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0% 0/21 [00:00<?, ?it/s]
# Epoch 2:  97% 34/35 [00:14<00:00,  2.41it/s, loss=0.699, val_loss=1.250]
# Epoch 2: 100% 35/35 [00:14<00:00,  2.47it/s, loss=0.699, val_loss=1.250]
# Epoch 3:  40% 14/35 [00:17<00:25,  1.22s/it, loss=0.68, val_loss=1.250]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0% 0/21 [00:00<?, ?it/s]
# Epoch 3:  97% 34/35 [00:18<00:00,  1.82it/s, loss=0.68, val_loss=1.250]
# Epoch 3: 100% 35/35 [00:18<00:00,  1.87it/s, loss=0.68, val_loss=1.460]
# Epoch 4:  40% 14/35 [00:20<00:31,  1.50s/it, loss=0.695, val_loss=1.460]
# Validation: 0it [00:00, ?it/s]
# Validation DataLoader 0:   0% 0/21 [00:00<?, ?it/s]
# Epoch 4:  97% 34/35 [00:22<00:00,  1.51it/s, loss=0.695, val_loss=1.460]
# Epoch 4: 100% 35/35 [00:22<00:00,  1.55it/s, loss=0.695, val_loss=1.430]
# Epoch 4: 100% 35/35 [00:22<00:00,  1.55it/s, loss=0.695, val_loss=1.430]
# Restoring states from the checkpoint path at ./data/STF_LOG_DIR/spatiotemporal_metr-la_21aa6d3c/spatiotemporal_metr-laepoch=02.ckpt
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/cloud_io.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location)
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from checkpoint at ./data/STF_LOG_DIR/spatiotemporal_metr-la_21aa6d3c/spatiotemporal_metr-laepoch=02.ckpt
# Testing: 0it [00:00, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Testing DataLoader 0: 100% 14/14 [00:01<00:00, 11.34it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/acc          │            1.0            │
# │      test/class_loss      │    0.00359281525015831    │
# │    test/forecast_loss     │    1.4420791864395142     │
# │         test/loss         │    1.4424381256103516     │
# │         test/mae          │    0.1393368894403631     │
# │         test/mape         │     73776.09090909091     │
# │         test/mse          │    0.04407996842355439    │
# │       test/norm_mae       │    0.7817255655924479     │
# │       test/norm_mse       │    1.4420644586736506     │
# │      test/recon_loss      │           -1.0            │
# │        test/smape         │    0.6400300228234493     │
# └───────────────────────────┴───────────────────────────┘
# tensor([[[0.8911, 0.1017],
#          [0.9010, 0.1007],
#          [0.8931, 0.1013],
#          [0.8939, 0.1064],
#          [0.8957, 0.1099],
#          [0.8911, 0.0972],
#          [0.8951, 0.1159],
#          [0.9006, 0.1088],
#          [0.8976, 0.1070],
#          [0.8924, 0.1144],
#          [0.8853, 0.1102],
#          [0.8954, 0.1099],
#          [0.8994, 0.1157],
#          [0.8830, 0.1086],
#          [0.8922, 0.1210],
#          [0.8921, 0.1041],
#          [0.8806, 0.1132],
#          [0.8883, 0.1003],
#          [0.8846, 0.0969],
#          [0.8957, 0.0967],
#          [0.8902, 0.1200],
#          [0.8863, 0.0910],
#          [0.8872, 0.1099],
#          [0.8786, 0.1133],
#          [0.8840, 0.0998],
#          [0.8852, 0.1080],
#          [0.8926, 0.1051],
#          [0.9023, 0.1113],
#          [0.8985, 0.1058],
#          [0.8794, 0.1069],
#          [0.8843, 0.1108],
#          [0.8866, 0.1042]],
#
#         [[0.8957, 0.1014],
#          [0.8958, 0.1032],
#          [0.8961, 0.1027],
#          [0.8913, 0.1028],
#          [0.8974, 0.0966],
#          [0.9013, 0.0982],
#          [0.8951, 0.1024],
#          [0.8930, 0.1122],
#          [0.9021, 0.1067],
#          [0.8926, 0.1168],
#          [0.8897, 0.1221],
#          [0.8898, 0.1133],
#          [0.8905, 0.0997],
#          [0.8902, 0.1090],
#          [0.8895, 0.1153],
#          [0.8766, 0.1114],
#          [0.8942, 0.0936],
#          [0.8856, 0.1186],
#          [0.8886, 0.1016],
#          [0.8872, 0.1022],
#          [0.8925, 0.1108],
#          [0.8929, 0.1006],
#          [0.8929, 0.1177],
#          [0.8902, 0.0786],
#          [0.8986, 0.1001],
#          [0.8938, 0.1197],
#          [0.8990, 0.1080],
#          [0.9002, 0.1072],
#          [0.8990, 0.1053],
#          [0.8930, 0.1011],
#          [0.8972, 0.1024],
#          [0.8824, 0.0976]],
#
#         [[0.8922, 0.1071],
#          [0.8945, 0.1116],
#          [0.8959, 0.1006],
#          [0.9022, 0.1056],
#          [0.8943, 0.0993],
#          [0.8987, 0.1047],
#          [0.8987, 0.1184],
#          [0.8970, 0.1200],
#          [0.8912, 0.1184],
#          [0.8895, 0.1118],
#          [0.8971, 0.1027],
#          [0.8893, 0.1102],
#          [0.8945, 0.1073],
#          [0.9010, 0.1115],
#          [0.8896, 0.1213],
#          [0.8946, 0.1043],
#          [0.8910, 0.1062],
#          [0.8902, 0.1188],
#          [0.8852, 0.0902],
#          [0.9001, 0.1050],
#          [0.8949, 0.1063],
#          [0.9071, 0.1056],
#          [0.8878, 0.0971],
#          [0.8873, 0.0904],
#          [0.8943, 0.1000],
#          [0.9015, 0.1237],
#          [0.9008, 0.0978],
#          [0.9009, 0.1145],
#          [0.8957, 0.1006],
#          [0.8929, 0.0951],
#          [0.8948, 0.1030],
#          [0.9007, 0.0951]],
#
#         [[0.8929, 0.1127],
#          [0.8894, 0.1091],
#          [0.8955, 0.1069],
#          [0.9010, 0.1108],
#          [0.8957, 0.0911],
#          [0.8984, 0.1087],
#          [0.8840, 0.1139],
#          [0.9002, 0.1062],
#          [0.8942, 0.1125],
#          [0.8893, 0.0917],
#          [0.8902, 0.1085],
#          [0.8939, 0.1210],
#          [0.8920, 0.1078],
#          [0.8860, 0.1063],
#          [0.8941, 0.1102],
#          [0.8973, 0.1080],
#          [0.8910, 0.1088],
#          [0.8939, 0.1134],
#          [0.8937, 0.0998],
#          [0.8958, 0.0977],
#          [0.9017, 0.1151],
#          [0.8897, 0.0950],
#          [0.8884, 0.1096],
#          [0.8993, 0.0962],
#          [0.8934, 0.0982],
#          [0.8896, 0.1053],
#          [0.8928, 0.1105],
#          [0.8887, 0.1051],
#          [0.8966, 0.1057],
#          [0.8878, 0.0873],
#          [0.8999, 0.1017],
#          [0.8949, 0.1171]],
#
#         [[0.8902, 0.1001],
#          [0.8948, 0.1014],
#          [0.8986, 0.1048],
#          [0.9049, 0.1018],
#          [0.8924, 0.1177],
#          [0.8923, 0.1113],
#          [0.9074, 0.1086],
#          [0.9041, 0.1082],
#          [0.8909, 0.1139],
#          [0.8920, 0.1043],
#          [0.8965, 0.1069],
#          [0.8843, 0.0994],
#          [0.8984, 0.1139],
#          [0.8836, 0.0983],
#          [0.8962, 0.1109],
#          [0.8924, 0.1077],
#          [0.8960, 0.1230],
#          [0.8854, 0.1066],
#          [0.8884, 0.1000],
#          [0.8968, 0.1064],
#          [0.8830, 0.1142],
#          [0.8901, 0.0965],
#          [0.8924, 0.0853],
#          [0.8890, 0.1068],
#          [0.8947, 0.1096],
#          [0.8910, 0.1087],
#          [0.9013, 0.0995],
#          [0.8898, 0.0963],
#          [0.8895, 0.0997],
#          [0.9027, 0.0882],
#          [0.8974, 0.1147],
#          [0.8897, 0.1131]]])
